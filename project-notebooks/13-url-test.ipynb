# %%
import requests
from readability import Document

# %%
url = 'https://www.politico.com/story/2016/06/transcript-bernie-sanders-speech-in-burlington-vermont-224465'

# %%
response = requests.get(url)
doc = Document(response.text)

# %%
candidates = doc.score_paragraphs()

# %%
candidates
# Out:
# {<Element figcaption at 0x10583ebd8>: {'content_score': 4.99,
#   'elem': <Element figcaption at 0x10583ebd8>},
#  <Element figure at 0x10583ec28>: {'content_score': 2.495,
#   'elem': <Element figure at 0x10583ec28>},
#  <Element div at 0x10583ed18>: {'content_score': 387.72084083746057,
#   'elem': <Element div at 0x10583ed18>},
#  <Element div at 0x10583ec78>: {'content_score': 208.06854738856373,
#   'elem': <Element div at 0x10583ec78>},
#  <Element div at 0x10583ecc8>: {'content_score': 7.877142857142857,
#   'elem': <Element div at 0x10583ecc8>},
#  <Element div at 0x10583ed68>: {'content_score': 6.081428571428572,
#   'elem': <Element div at 0x10583ed68>}}

# %%
best = doc.select_best_candidate(candidates)

# %%
doc.get_article

# %%
doc.get_article(candidates, best)
# Out:
# <Element html at 0x105847c78>

# %%
doc.content()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/readability/htmls.py:117: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   raw_html = str_(tostring(doc.body or doc))
# ...
